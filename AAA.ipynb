#
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2408.000000  2408.000000  2408.000000  2408.000000  2408.000000
# mean    231.842600   233.350025   230.103335   231.791250   231.791250
# std      78.065907    78.579086    77.476308    78.063048    78.063048
# min     124.110001   125.839996   123.550003   124.129997   124.129997
# 25%     169.422493   170.149994   168.237499   169.470001   169.470001
# 50%     208.495003   210.125000   206.985001   208.514999   208.514999
# 75%     289.497513   290.779991   287.210007   289.239990   289.239990
# max     445.619995   449.250000   439.570007   445.609985   445.609985
#
#              Volume
# count  2.408000e+03
# mean   4.142750e+06
# std    1.930693e+06
# min    6.720000e+04
# 25%    2.987100e+06
# 50%    3.654650e+06
# 75%    4.684800e+06
# max    2.229380e+07

# %%
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-01-02  151.500000  151.600006  148.500000  149.169998  149.169998
# 1  2015-01-05  148.809998  149.000000  146.779999  147.000000  147.000000
# 2  2015-01-06  147.639999  148.529999  146.110001  146.839996  146.839996
# 3  2015-01-07  147.940002  149.139999  147.649994  148.880005  148.880005
# 4  2015-01-08  150.600006  151.369995  150.509995  151.369995  151.369995
#
#     Volume
# 0  3436400
# 1  4168800
# 2  4116100
# 3  4159100
# 4  4282100

# %%
data.shape
# Out:
# (2408, 7)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
data.drop_duplicates(keep='first', inplace=True, ignore_index=False)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
data.nunique()
# Out:
# Date         2408
# Open         2210
# High         2224
# Low          2217
# Close        2234
# Adj Close    2234
# Volume       2330
# dtype: int64

# %%
# 1. Line Plot: Close price over time
plt.figure(figsize=(10, 6))
plt.plot(data['Date'], data['Close'], label='Close Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close Price Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(data['Date'], data['Volume'], label='Volume')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Volume Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(9, 6))
plt.scatter(data['High'], data['Low'], alpha=0.5, label='High vs. Low')
plt.xlabel('High Price')
plt.ylabel('Low Price')
plt.title('High vs. Low Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 6. Open vs. Close Scatter Plot
plt.figure(figsize=(10, 6))
plt.scatter(data['Open'], data['Close'], alpha=0.5, label='Open vs. Close')
plt.xlabel('Open Price')
plt.ylabel('Close Price')
plt.title('Open vs. Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 7. Correlation Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
mask = np.triu(np.ones_like(data.corr(), dtype=bool))
sns.heatmap(data.corr(), annot=True, mask=mask, fmt='.2f', vmin=0)
# Out:
# <Axes: >

# %%
data.head(1)
# Out:
#          Date   Open        High    Low       Close   Adj Close   Volume
# 0  2015-01-02  151.5  151.600006  148.5  149.169998  149.169998  3436400

# %%
sns.regplot(x='High',y='Volume',data=data,fit_reg=True,line_kws={"color":"red"})
# Out:
# <Axes: xlabel='High', ylabel='Volume'>

# %%
sns.violinplot(x='Open',y='High',data=data)
# Out:
# <Axes: xlabel='Open', ylabel='High'>

# %%
data.head(1)
# Out:
#          Date   Open        High    Low       Close   Adj Close   Volume
# 0  2015-01-02  151.5  151.600006  148.5  149.169998  149.169998  3436400

# %%
# Lets compute the Interquantile range to calculate the boundaries
IQR=data.Open.quantile(0.75)-data.Open.quantile(0.25)
print(IQR)
# Out:
# 120.07501983642578

# %%
lower_bridge=data['Op'].quantile(0.25)-(IQR*1.5)
upper_bridge=data['Open'].quantile(0.75)+(IQR*1.5)
print("Lower_Bridge:",lower_bridge)
print("Upper_Bridge: ",upper_bridge)
# Out:
# Lower_Bridge: -10.69003677368164
# Upper_Bridge:  469.6100425720215

# %%
data.loc[data['Open']>=18454.0,'price']=18454.0

# %%
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-01-02  151.500000  151.600006  148.500000  149.169998  149.169998
# 1  2015-01-05  148.809998  149.000000  146.779999  147.000000  147.000000
# 2  2015-01-06  147.639999  148.529999  146.110001  146.839996  146.839996
# 3  2015-01-07  147.940002  149.139999  147.649994  148.880005  148.880005
# 4  2015-01-08  150.600006  151.369995  150.509995  151.369995  151.369995
#
#     Volume  price
# 0  3436400    NaN
# 1  4168800    NaN
# 2  4116100    NaN
# 3  4159100    NaN
# 4  4282100    NaN

# %%
# Perform label encoding on the specified columns and display the unique values for each encoded column. 
# Finally, it will print the updated DataFram

def LABEL_ENCODING(c1):
    from sklearn import preprocessing
    label_encoder = preprocessing.LabelEncoder()
    data[c1]= label_encoder.fit_transform(data[c1])
    data[c1].unique()
LABEL_ENCODING("High")
LABEL_ENCODING("Low")
LABEL_ENCODING("Close")
data
# Out:
#             Date        Open  High   Low  Close   Adj Close   Volume  price
# 0     2015-01-02  151.500000   403   382    396  149.169998  3436400    NaN
# 1     2015-01-05  148.809998   371   354    357  147.000000  4168800    NaN
# 2     2015-01-06  147.639999   363   343    353  146.839996  4116100    NaN
# 3     2015-01-07  147.940002   373   367    390  148.880005  4159100    NaN
# 4     2015-01-08  150.600006   402   399    415  151.369995  4282100    NaN
# ...          ...         ...   ...   ...    ...         ...      ...    ...
# 2403  2024-07-23  437.339996  2215  2211   2225  434.010010  2393000    NaN
# 2404  2024-07-24  433.989990  2214  2207   2223  432.799988  3143700    NaN
# 2405  2024-07-25  431.600006  2220  2208   2224  433.290009  3334300    NaN
# 2406  2024-07-26  435.660004  2217  2213   2229  437.660004  2717600    NaN
# 2407  2024-07-29  438.010010  2219  2214   2230  438.309998  2620000    NaN
#
# [2408 rows x 8 columns]

# %%
X = data.drop('Adj Close',axis=1)

# %%
y = data['Adj Close']

# %%
#splitting the dataset
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1926, 7)
# (482, 7)
# (1926,)
# (482,)

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %matplotlib inline

Av = AutoViz_Class()

viz = Av.AutoViz('Stock.csv', sep=',')
# Out:
# Imported v0.1.901. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (2408, 7)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  5
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
# ...

# %%
Av = AutoViz_Class()

viz = Av.AutoViz('iris.csv', sep=',', chart_format='html')
